# %%
# %matplotlib widget

# %%
import sys
sys.path.append('../external/tslib')

import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import csv
import os
import json
import time
import matplotlib.pyplot as plt

seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
from dataclasses import dataclass
from typing import List, Optional


@dataclass
class Task:
    id: str
    request_time: int
    duration: int
    start_time: Optional[int] = None
    end_time: Optional[int] = None
    assigned_worker: Optional[str] = None

    def __str__(self):
        return f"Task({self.id}|{self.duration}ms|{self.assigned_worker}|{self.request_time}-{self.start_time}-{self.end_time})"

@dataclass
class MetricsDataPoint:
    time: int
    expected_workers: int
    active_workers: int
    total_workers: int
    num_new_tasks: int
    num_ongoing_tasks: int
    num_queued_tasks: int
    num_completed_tasks: int
    avg_delay: float
    avg_duration: float
    reward: float
    completed_tasks: List[Task]
    
def generate_reward_function(metrics_window: float, value_per_task: float = 0.001, cost_per_worker_hour: float = 1, delay_threshold: int = 8000) -> float:
    # Example reward function: negative of average delay
    return lambda metrics: (
        sum([0 if (task.end_time - task.request_time) > delay_threshold else value_per_task for task in metrics.completed_tasks]) -
        cost_per_worker_hour * (metrics.total_workers * metrics_window / 3600000 )
    )

class Worker:
    def __init__(self, init_time: int = 0):
        self.id = "worker-" + str(random.randint(0, 10000))
        self.available_at = init_time
        self.active = False  # 是否已经初始化完成

    def assign_task(self, task: Task, current_time: int):
        if current_time < self.available_at:
            task.start_time = self.available_at
            self.available_at += task.duration
        else:
            task.start_time = current_time
            self.available_at = current_time + task.duration
        task.end_time = self.available_at
        task.assigned_worker = self.id
    
    def is_available(self, current_time: int) -> bool:
        return self.available_at <= current_time and self.active
    


class Simulator:
    def __init__(self, tasks: List[Task], init_workers: int = 1, worker_init_time : int = 1200, metrics_window: int = 10000, reward_function=None):
        self.tasks = sorted(tasks, key=lambda t: t.request_time)
        self.time = 0  
        self.metrics_window = metrics_window
        self.worker_init_time = worker_init_time
        self.expected_workers = init_workers
        self.workers = [Worker(worker_init_time) for i in range(init_workers)]
        self.terminating_workers: List[Task] = []
        self.in_progress: List[Task] = []
        self.queued: List[Task] = []
        self.completed_tasks: List[Task] = []

        self.new_tasks = 0
        self.metrics: List[MetricsDataPoint] = []
        self.reward_function = reward_function

    def tick(self): # tick 1s
        self.time += 1000
        # check completed tasks
        for task in self.in_progress:
            if task.end_time <= self.time:
                self.completed_tasks.append(task)
                self.in_progress.remove(task)
        # check initialized workers
        for w in self.workers:
            if not w.active and self.time >= w.available_at:
                w.active = True
        # check terminating workers
        self.terminating_workers = [w for w in self.terminating_workers if w.available_at >= self.time]
        
        worker = self.get_available_worker(self.time)
        # pop queued tasks
        while worker and self.queued:
            task = self.queued.pop(0)
            worker.assign_task(task, task.request_time)
            self.in_progress.append(task)
            worker = self.get_available_worker(self.time)
        # pop new tasks
        while self.tasks and self.tasks[0].request_time < self.time:
            task = self.tasks.pop(0)
            self.new_tasks += 1
            if worker:
                worker.assign_task(task, self.time)
                self.in_progress.append(task)
                worker = self.get_available_worker(self.time)
            else:
                self.queued.append(task)
        # report metrics
        if self.time % self.metrics_window == 0:
            self.report_metrics()

    def scale(self, expected_workers: int):
        if expected_workers > self.expected_workers:
            for i in range(expected_workers - self.expected_workers):
                worker = Worker(self.time + self.worker_init_time)
                self.workers.append(worker)
        elif expected_workers < self.expected_workers:
            for i in range(self.expected_workers - expected_workers):
                worker = self.workers.pop()
                self.terminating_workers.append(worker)
        self.expected_workers = expected_workers


    def report_metrics(self):
        if self.completed_tasks:
            avg_delay = int(np.mean([t.end_time - t.request_time for t in self.completed_tasks]))
            avg_duration = int(np.mean([t.end_time - t.start_time for t in self.completed_tasks]))
        else:
            avg_delay = 0
            avg_duration = 0
        dataPoint = MetricsDataPoint(
            time=self.time,
            expected_workers=self.expected_workers,
            active_workers=len([w for w in self.workers if w.active]),
            total_workers=len(self.workers) + len(self.terminating_workers),
            num_new_tasks=self.new_tasks,
            num_ongoing_tasks=len(self.in_progress) + len(self.queued),
            num_queued_tasks=len(self.queued),
            num_completed_tasks=len(self.completed_tasks),
            avg_delay=avg_delay,
            avg_duration=avg_duration,
            completed_tasks=self.completed_tasks.copy(),
            reward=0,  # Placeholder for reward, to be calculated later
        )
        if self.reward_function:
            dataPoint.reward = self.reward_function(dataPoint)
        self.metrics.append(dataPoint)
        self.completed_tasks.clear()
        self.new_tasks = 0

    def get_available_worker(self, current_time: int) ->Optional[Worker]:
        # FIFO
        available_workers = sorted(
            [w for w in self.workers if w.is_available(current_time)], 
            key=lambda w: w.available_at
        )
        if available_workers:
            return available_workers[0]
        else:
            return None
        
    def plot_metrics(self, tmp_output_dir: str = None):
        metric_keys = [
            'expected_workers',
            'active_workers',
            'total_workers',
            'num_new_tasks',
            'num_ongoing_tasks',
            'num_queued_tasks',
            'num_completed_tasks',
            'avg_delay',
            'avg_duration',
            'reward'
        ]

        data = {key: [] for key in metric_keys}
        time_s = [int(m.time / 1000) for m in self.metrics]

        for metrics in self.metrics:
            for key in metric_keys:
                data[key].append(getattr(metrics, key))

        fig, axes = plt.subplots(len(metric_keys), 1, figsize=(14, 20), sharex=True)

        for ax, key in zip(axes, metric_keys):
            ax.plot(time_s, data[key], label=key)
            ax.set_ylabel(key)
            ax.grid(True)
            ax.legend(loc='upper left')

        axes[-1].set_xlabel("Time (s)")
        fig.tight_layout()
        if tmp_output_dir:
            plt.savefig(os.path.join(tmp_output_dir, "metrics_plot.png"), dpi=300)
        else:
            plt.show()

# %%
from datetime import timedelta

def extract_continuous_segment(df, week_count, day_count, time_scale, request_scale):
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s')
    df.sort_values('timestamp', inplace=True)
    df.reset_index(drop=True, inplace=True)

    # 设置时间戳为索引
    df.set_index('timestamp', inplace=True)

    # 获取数据的起始和结束时间
    start_time = df.index.min()
    end_time = df.index.max()

    # 计算所需的总天数
    total_days = week_count * 7 + day_count

    # 查找所有满足条件的连续时间段
    valid_starts = []
    if week_count > 0:
        # 计算所有可能的周一 00:00 的时间点
        valid_starts = pd.date_range(start=start_time, end=end_time - timedelta(days=total_days), freq='W-MON')
    else:
        # 计算所有可能的起始时间点
        valid_starts = pd.date_range(start=start_time, end=end_time - timedelta(days=total_days), freq='D')

    if valid_starts.empty:
        print("❌ 数据中没有满足条件的连续时间段。")
        return

    # 随机选择一个起始时间
    selected_start = random.choice(valid_starts)
    selected_end = selected_start + timedelta(days=total_days)
    print(f"✅ 选中的时间段：{selected_start} 到 {selected_end}")

    # 提取选中的数据段
    segment = df.loc[selected_start:selected_end].copy()
    if segment.empty:
        print("⚠️ 选中的时间段内没有数据。")
        return

    # 重置时间戳，从 0 开始，并应用时间缩放
    segment.reset_index(inplace=True)
    base_time = segment['timestamp'].min()
    segment['timestamp'] = segment['timestamp'].apply(lambda x: int((x - base_time).total_seconds() / time_scale))

    # 应用请求数缩放
    segment['requests'] = segment['requests'] / request_scale

    return segment[['timestamp', 'requests']].reset_index(drop=True), base_time.tz_localize("UTC")

def schedule_requests_from_csv(requests_df, rate_df):
    # 打乱请求顺序
    requests_df = requests_df.sample(frac=1).reset_index(drop=True)

    result_rows = []
    request_index = 0
    accum = 0.0  # 累积速率

    for _, rate_row in rate_df.iterrows():
        timestamp_base = float(rate_row['timestamp'])
        rps = float(rate_row['requests'])

        accum += rps
        num_requests = int(accum)
        accum -= num_requests  # 保留小数部分

        for _ in range(num_requests):
            if request_index >= len(requests_df):
                break
            row = requests_df.iloc[request_index].copy()
            # 在[T, T+1)内均匀分布]
            row['timestamp'] = timestamp_base + random.uniform(0, 1)
            result_rows.append(row)
            request_index += 1

        if request_index >= len(requests_df):
            break
    
    # sort by timestamp
    result_rows.sort(key=lambda x: x['timestamp'])

    # 创建结果 DataFrame
    return pd.DataFrame(result_rows, columns=['Id', 'Duration', 'timestamp']).rename(columns={'Id': 'id', 'Duration': 'duration'})

def generate_tasks_from_csv(requests_csv_path, rate_csv_path, week_count=0, day_count=3, scale = 0.8, tmp_output_dir = None):
    # 读取请求数据
    requests_df = pd.read_csv(requests_csv_path)
    rate_df = pd.read_csv(rate_csv_path)

    # 提取连续时间段
    segment, base_time = extract_continuous_segment(rate_df, week_count, day_count, 120, 120 * 1 / scale)
    if segment is None:
        return None
    
    tasks_df = schedule_requests_from_csv(requests_df, segment)
    if tasks_df is None:
        return None
    
    time_start = tasks_df['timestamp'].min() 
    tasks_df['timestamp'] = tasks_df['timestamp'].apply(lambda x: int((x - time_start) * 1000))  # 转换为毫秒
    tasks_df['id'] = tasks_df['id'].astype(int)
    tasks_df['duration'] = tasks_df['duration'].astype(int)

    if tmp_output_dir:
        tmp_output_path = os.path.join(tmp_output_dir, 'tasks.csv')
        if not os.path.exists(tmp_output_dir):
            os.makedirs(tmp_output_dir)
        tasks_df.to_csv(tmp_output_path, index=False)
        print(f"✅ 生成的任务数据已保存到 {tmp_output_path}")
        # 保存basetime等元信息为json文件
        meta_info = {'base_time': base_time.isoformat(), 'week_count': week_count, 'day_count': day_count, 'scale': scale}
        meta_info_path = os.path.join(tmp_output_dir, 'meta_info.json')
        with open(meta_info_path, 'w') as f:
            json.dump(meta_info, f)
        print(f"✅ 生成的元数据已保存到 {meta_info_path}")

    tasks = [Task(id=row['id'], request_time=row['timestamp'], duration=row['duration']) for _, row in tasks_df.iterrows()]
    return tasks, base_time

def load_tasks_from_csv(tmp_output_dir = './tmp'):
    tasks_df = pd.read_csv(os.path.join(tmp_output_dir, 'tasks.csv'))
    tasks = [Task(id=row['id'], request_time=row['timestamp'], duration=row['duration']) for _, row in tasks_df.iterrows()]
    # 读取元信息
    with open(os.path.join(tmp_output_dir, 'meta_info.json'), 'r') as f:
        meta_info = json.load(f)
        base_time = pd.to_datetime(meta_info['base_time'])

    return tasks, base_time

def save_metrics_to_csv(metric_history, tmp_output_dir):
    os.makedirs(tmp_output_dir, exist_ok=True)

    # Build DataFrame
    df = pd.DataFrame(metric_history)
    df['time'] = df['time'].apply(lambda x: int(x / 1000)) 
    df['reward'] = df['reward'].apply(lambda x: round(x, 4))
    df['completed_tasks'] = df['completed_tasks'].apply(lambda x: ','.join([f"Task({t['id']}|{t['duration']}ms|{t['assigned_worker']}|{t['request_time']}-{t['start_time']}-{t['end_time']})" for t in x]))

    # Write to CSV
    out_path = os.path.join(tmp_output_dir, 'metrics.csv')
    df.to_csv(out_path, index=False)
    print(f"✅ 生成的指标数据已保存到 {out_path}")

# %%
day_count = 3
scale = 1.5
iterations = 60 * 12 * day_count
init_workers = 1
min_workers = 1
max_workers = 6
worker_init_time = 12
metrics_window = 10
forecast_window = 36
reward_function = generate_reward_function(metrics_window * 1000, value_per_task=0.002, cost_per_worker_hour=1, delay_threshold=8000)

# %%
tasks, base_time = generate_tasks_from_csv(
    requests_csv_path='../data/train_regression_clipped.csv',
    rate_csv_path='../data/request_timeseries_train.csv',
    week_count=0,
    day_count=day_count,
    scale=scale,
    tmp_output_dir='./tmp'
)
# Out:
# ✅ 选中的时间段：2025-02-22 13:00:00 到 2025-02-25 13:00:00
# ✅ 生成的任务数据已保存到 ./tmp/tasks.csv
# ✅ 生成的元数据已保存到 ./tmp/meta_info.json

# %%
tasks, _ = load_tasks_from_csv('./tmp')
simulator = Simulator(tasks, 1, worker_init_time * 1000, metrics_window * 1000,
                      reward_function=reward_function
)
for i in range(iterations):
    simulator.tick()

print("🤩 总reward为：", sum([m.reward for m in simulator.metrics]))
simulator.plot_metrics("./tmp")
save_metrics_to_csv(simulator.metrics, './tmp')
# Out:
# 🤩 总reward为： -0.5999999999999984
# ✅ 生成的指标数据已保存到 ./tmp/metrics.csv
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
class QueueSizeScaleStrategy:
    def __init__(self, 
                 min_workers: int = 1,
                 max_workers: int = 6,
                 aggressive_scale: bool = False,
                 target_ongoing_tasks: int = 3, 
                 scale_up_window: int = 1, 
                 scale_down_window: int = 1):
        self.min_workers = min_workers
        self.max_workers = max_workers
        self.aggressive_scale = aggressive_scale
        self.target_ongoing_tasks = target_ongoing_tasks
        self.scale_up_window = scale_up_window
        self.scale_down_window = scale_down_window

    def calc(self, current_expected_workers: int, metrics: List[MetricsDataPoint]) -> int:
        if len(metrics) < self.scale_up_window or len(metrics) < self.scale_down_window:
            return current_expected_workers
        # Calculate the average number of ongoing tasks over the last scale_up_window iterations
        avg_ongoing_tasks_up = np.mean([m.num_ongoing_tasks + m.num_new_tasks for m in metrics[-self.scale_up_window:]])
        # Calculate the average number of ongoing tasks over the last scale_down_window iterations
        avg_ongoing_tasks_down = np.mean([m.num_ongoing_tasks + m.num_new_tasks for m in metrics[-self.scale_down_window:]])
        # Scale up if the average number of ongoing tasks is greater than the target
        new_workers = current_expected_workers
        running_workers = max(1, metrics[-1].active_workers)
        if avg_ongoing_tasks_up > self.target_ongoing_tasks * running_workers:
            new_workers = np.ceil(avg_ongoing_tasks_up / self.target_ongoing_tasks)
            if not self.aggressive_scale and new_workers > current_expected_workers:
                new_workers = current_expected_workers + 1
            new_workers = min(new_workers, self.max_workers)

        if avg_ongoing_tasks_down < self.target_ongoing_tasks * running_workers:
            new_workers = np.ceil(avg_ongoing_tasks_down / self.target_ongoing_tasks)
            if not self.aggressive_scale and new_workers < current_expected_workers:
                new_workers = current_expected_workers - 1
            new_workers = max(new_workers, self.min_workers)

        return int(new_workers)

# %%
strategy = QueueSizeScaleStrategy(
    min_workers=min_workers,
    max_workers=max_workers,
    aggressive_scale=True,
    target_ongoing_tasks=5,
    scale_up_window=1,
    scale_down_window=1
)
tasks, _ = load_tasks_from_csv('./tmp')
simulator = Simulator(tasks, init_workers, worker_init_time * 1000, metrics_window * 1000,
                      reward_function=reward_function
)
for i in range(iterations):
    simulator.tick()
    if i > 0 and i % metrics_window == 0:
        expected_workers = strategy.calc(simulator.expected_workers, simulator.metrics)
        simulator.scale(expected_workers)
print("🤩 总reward为：", sum([m.reward for m in simulator.metrics]))
simulator.plot_metrics("./tmp")
save_metrics_to_csv(simulator.metrics, './tmp')
# Out:
# 🤩 总reward为： 1.1610000000000038
# ✅ 生成的指标数据已保存到 ./tmp/metrics.csv
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import gymnasium as gym
from gymnasium.spaces import Discrete, Box
from tslib_util import (
    TimeseriesForecaster,
    TimeseriesTransformer
)

class WorkerScaling(gym.Env):

    FEATURE_MIN = {
        "running_workers": 0,
        "new_requests": 0,
        "ongoing_requests": 0,
        "finished_requests": 0,
        "requests_delay": 0.0,
        "requests_duration": 0.0,
        "forecasted_requests": 0.0,
    }

    FEATURE_MAX = {
        "running_workers": max_workers,         
        "new_requests": scale * 10,            
        "ongoing_requests": scale * 50,        
        "finished_requests": max_workers * 6,       
        "requests_delay": scale * 20000,          
        "requests_duration": 12000, 
        "forecasted_requests": scale * 10,      
    }

    def __init__(self, config: Optional[dict] = None):
        self.config = config or {}
        self.observe_length = self.config.get("observe_length", 36)
        self.action_space = Discrete(max_workers)
        self.observation_space = Box(0.0, 1.0, shape=(self.observe_length* 7,), dtype=np.float32)
        self.time_s = 0

        self.forecaster = TimeseriesForecaster()

        random.seed(int(seed + self.config.get("worker_index", 0)) % 99999)
        np.random.seed(int(seed + self.config.get("worker_index", 0)) % 99999)


    def reset(self, *, seed=None, options=None):
        self.time_s = 0
        self.init_simulator()
        # Return obs and (empty) info dict.
        return self.extract_observation_window(self.simulator.metrics), {"env_state": "reset"}

    def step(self, action):
        assert action in range(max_workers), f"Invalid action {action}"
        
        self.simulator.scale(action + min_workers)
        for _ in range(metrics_window):
            self.simulator.tick()
            self.time_s += 1
            if self.time_s >= iterations:
                break

        # The environment only ever terminates when we reach the goal state.
        terminated = self.time_s >= iterations
        truncated = False

        # if terminated:
        #     print(f"🤩 总reward为 {sum([m.reward for m in self.simulator.metrics])}")
        #     self.simulator.plot_metrics("./tmp")
        #     save_metrics_to_csv(self.simulator.metrics, './tmp')

        reward = self.simulator.metrics[-1].reward
        infos = {}
        return (
            self.extract_observation_window(self.simulator.metrics),
            reward,
            terminated,
            truncated,
            infos,
        )
    
    def init_simulator(self, tasks=None, base_time=None):
        if tasks is None:
            tasks, base_time = generate_tasks_from_csv(
                requests_csv_path='../data/train_regression_clipped.csv',
                rate_csv_path='../data/request_timeseries_train.csv',
                week_count=0,
                day_count=day_count,
                scale=scale,
            )
        self.simulator = Simulator(tasks, 1, worker_init_time * 1000, metrics_window * 1000, reward_function)

        self.forecaster.setTransformer(
            transformer=TimeseriesTransformer(
                date_start=base_time.timestamp(), date_scale=120, scale=True,
                scale_mean=3.69210541, scale_std=2.06017052
            )
        )

        self.iteration = 0
        self.max_iterations = len(tasks) * 2

    
    def extract_observation_window(self, data: List[MetricsDataPoint]) -> np.ndarray:

        # get forecasted data

        obs = np.zeros((7, self.observe_length), dtype=np.float32)
        recent = data[-self.observe_length:] if len(data) >= self.observe_length else [None] * (self.observe_length - len(data)) + data

        forecast_metrics =  data[-forecast_window:] if len(data) >= forecast_window else [None] * (forecast_window - len(data)) + data
        recent_new_request = [0 if not m else m.num_new_tasks for m in forecast_metrics]
        recent_timestamp = [self.time_s - (forecast_window + i + 1) * metrics_window for i in range(forecast_window)]
        obs[-1] = self.forecaster.forecast(
            enc_data=recent_new_request,
            enc_stamp=recent_timestamp,
        )[:self.observe_length]

        for i, point in enumerate(recent):
            if point is None:
                continue  # Keep default zeros for padding

            features = [
                ("running_workers", point.active_workers),
                ("new_requests", point.num_new_tasks),
                ("ongoing_requests", point.num_ongoing_tasks),
                ("finished_requests", point.num_completed_tasks),
                ("requests_delay", point.avg_delay),
                ("requests_duration", point.avg_duration),
                ("forecasted_requests", obs[-1][i]),
            ]

            for row, (key, raw_value) in enumerate(features):
                min_val = WorkerScaling.FEATURE_MIN[key]
                max_val = WorkerScaling.FEATURE_MAX[key]
                # Min-max normalization with small epsilon for safety
                norm_val = (raw_value - min_val) / (max_val - min_val + 1e-6)
                norm_val = np.clip(norm_val, 0.0, 1.0)  # 防止越界
                obs[row, i] = norm_val

        # flatten the observation to 1D array
        obs = obs.flatten()

        return obs

# %%
from ray.tune import Callback
from ray.rllib.utils.test_utils import (
    add_rllib_example_script_args,
    run_rllib_example_script_experiment,
)
from ray.rllib.utils.metrics import (
    ENV_RUNNER_RESULTS,
    EPISODE_RETURN_MEAN,
)
from ray.rllib.core.rl_module.default_model_config import DefaultModelConfig
from ray.rllib.algorithms.ppo.torch.default_ppo_torch_rl_module import (
    DefaultPPOTorchRLModule
)
from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.core.rl_module.rl_module import RLModuleSpec

import importlib
import transformer

importlib.reload(transformer)


parser = add_rllib_example_script_args(
    default_reward=1.5, default_iters=400, default_timesteps=1000000
)
parser.set_defaults(
    # Make sure that - by default - we produce checkpoints during training.
    # checkpoint_freq=10,
    # checkpoint_at_end=True,
    # Use CartPole-v1 by default.
    # Script only runs on new API stack.
    enable_new_api_stack=True,
)
args = parser.parse_args([])

iter_setps, episode_reward = [], []
class TuneCallback(Callback):
    def on_trial_result(self, iteration, trials, trial, result,
                        **info):
        if result.get(ENV_RUNNER_RESULTS) and result.get(ENV_RUNNER_RESULTS).get(EPISODE_RETURN_MEAN):
            print(f"🤩 step{iteration} 平均reward为 {result[ENV_RUNNER_RESULTS][EPISODE_RETURN_MEAN]}")
            iter_setps.append(iteration)
            episode_reward.append(result[ENV_RUNNER_RESULTS][EPISODE_RETURN_MEAN])

base_config = (
        PPOConfig()
        .api_stack(
            enable_rl_module_and_learner=True,
            enable_env_runner_and_connector_v2=True,
        )
        .rl_module(
            # Use a non-default 32,32-stack with ReLU activations.
            model_config=DefaultModelConfig(
                # fcnet_hiddens=[128, 128],
                # fcnet_activation="relu",
                # head_fcnet_hiddens=[32, 32],
                vf_share_layers=True,
            )
        )
        # .rl_module(
        #     rl_module_spec=RLModuleSpec(
        #         module_class=DefaultPPOTorchRLModule,
        #         catalog_class=transformer.TransformerEncoderCatalog,
        #         model_config={
        #             # "head_fcnet_hiddens": [256, 256],
        #             # "head_fcnet_activation": "relu",
        #             "vf_share_layers": True,
        #             "d_model": 32,
        #             "embedding_dropout": 0,
        #         },
        #     ),
        # )
        .env_runners(num_env_runners=8, num_gpus_per_env_runner=0, num_cpus_per_env_runner=0.1)
        .learners(num_gpus_per_learner=1, num_cpus_per_learner=1)
        .training(
            train_batch_size_per_learner = 2000,
        )
        .environment(
            WorkerScaling,
            env_config={"observe_length": 6}
        )
    )

results = run_rllib_example_script_experiment(base_config, args, tune_callbacks=[TuneCallback()])

best_result = results.get_best_result(
    metric=f"{ENV_RUNNER_RESULTS}/{EPISODE_RETURN_MEAN}", mode="max"
)
print(f"Best result: {best_result}")
# Out:
# 2025-05-11 05:54:45,937	INFO worker.py:1888 -- Started a local Ray instance.
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-05-11 08:09:27</td></tr>
# <tr><td>Running for: </td><td>02:14:39.90        </td></tr>
# <tr><td>Memory:      </td><td>7.8/15.5 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.8000000000000007/8 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                   </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  num_training_step_ca
# lls_per_iteration</th><th style="text-align: right;">       num_env_steps_sample
# d_lifetime</th><th style="text-align: right;">        ...env_steps_sampled
# _lifetime_throughput</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_WorkerScaling_a0813_00000</td><td>RUNNING </td><td>192.168.1.107:51560</td><td style="text-align: right;">   197</td><td style="text-align: right;">         8023.99</td><td style="text-align: right;">1</td><td style="text-align: right;">394000</td><td style="text-align: right;">47.9113</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# (PPO pid=51560) 2025-05-11 05:54:56,040	WARNING algorithm_config.py:4766 -- You are running PPO on the new API stack! This is the new default behavior for this algorithm. If you don't want to use the new API stack, set `config.api_stack(enable_rl_module_and_learner=False,enable_env_runner_and_connector_v2=False)`. For a detailed migration guide, see here: https://docs.ray.io/en/master/rllib/new-api-stack-migration-guide.html
# (SingleAgentEnvRunner pid=51625) Using cpu or mps
# (SingleAgentEnvRunner pid=51625) Use CPU
# (SingleAgentEnvRunner pid=51625) 2025-05-11 05:55:15,611	WARNING deprecation.py:50 -- DeprecationWarning: `RLModule(config=[RLModuleConfig object])` has been deprecated. Use `RLModule(observation_space=.., action_space=.., inference_only=.., model_config=.., catalog_class=..)` instead. This will raise an error in the future!
# (PPO pid=51560) Trainable.setup took 22.584 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (PPO pid=51560) Install gputil for GPU system monitoring.
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-05 13:00:00 到 2025-01-08 13:00:00
# (SingleAgentEnvRunner pid=51629) Using cpu or mps [repeated 7x across cluster]
# (SingleAgentEnvRunner pid=51629) Use CPU [repeated 7x across cluster]
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-02-22 13:00:00 到 2025-02-25 13:00:00 [repeated 8x across cluster]
# 🤩 step782 平均reward为 -0.6174999999999995
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name                   </th><th>env_runner_group                               </th><th>env_runners                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               </th><th>fault_tolerance                                            </th><th>learners                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# </thead>
# <tbody>
# <tr><td>PPO_WorkerScaling_a0813_00000</td><td>{&#x27;actor_manager_num_outstanding_async_reqs&#x27;: 0}</td><td>{&#x27;module_episode_returns_mean&#x27;: {&#x27;default_policy&#x27;: 0.8569658119658138}, &#x27;env_to_module_connector&#x27;: {&#x27;timers&#x27;: {&#x27;connectors&#x27;: {&#x27;add_time_dim_to_batch_and_zero_pad&#x27;: np.float64(3.815440857907775e-05), &#x27;numpy_to_tensor&#x27;: np.float64(0.00016533352364738442), &#x27;add_states_from_episodes_to_batch&#x27;: np.float64(1.9489993799315894e-05), &#x27;batch_individual_items&#x27;: np.float64(9.423757505503698e-05), &#x27;add_observations_from_episodes_to_batch&#x27;: np.float64(3.908466598084334e-05)}}, &#x27;connector_pipeline_timer&#x27;: np.float64(0.0005975134642284587)}, &#x27;num_module_steps_sampled&#x27;: {&#x27;default_policy&#x27;: 2000}, &#x27;num_episodes&#x27;: 16, &#x27;env_to_module_sum_episodes_length_in&#x27;: np.float64(96.90217702112001), &#x27;num_env_steps_sampled&#x27;: 2000, &#x27;num_agent_steps_sampled&#x27;: {&#x27;default_agent&#x27;: 2000}, &#x27;rlmodule_inference_timer&#x27;: np.float64(0.0005520652274458788), &#x27;episode_len_max&#x27;: 216, &#x27;agent_episode_returns_mean&#x27;: {&#x27;default_agent&#x27;: 0.8569658119658138}, &#x27;episode_len_mean&#x27;: 216.0, &#x27;module_to_env_connector&#x27;: {&#x27;timers&#x27;: {&#x27;connectors&#x27;: {&#x27;un_batch_to_individual_items&#x27;: np.float64(6.867735272668181e-05), &#x27;remove_single_ts_time_rank_from_batch&#x27;: np.float64(7.802360381821858e-06), &#x27;listify_data_for_vector_env&#x27;: np.float64(0.00013480365940378062), &#x27;get_actions&#x27;: np.float64(0.000706124885082818), &#x27;tensor_to_numpy&#x27;: np.float64(0.00022647541676187497), &#x27;normalize_and_clip_actions&#x27;: np.float64(0.00011949663555757771)}}, &#x27;connector_pipeline_timer&#x27;: np.float64(0.0015778870152950459)}, &#x27;num_module_steps_sampled_lifetime&#x27;: {&#x27;default_policy&#x27;: 394000}, &#x27;env_step_timer&#x27;: np.float64(0.1092624012128406), &#x27;episode_duration_sec_mean&#x27;: 21.992496384163204, &#x27;num_episodes_lifetime&#x27;: 1824, &#x27;episode_return_min&#x27;: 0.6165555555555567, &#x27;weights_seq_no&#x27;: 196.0, &#x27;episode_len_min&#x27;: 216, &#x27;num_agent_steps_sampled_lifetime&#x27;: {&#x27;default_agent&#x27;: 394000}, &#x27;sample&#x27;: np.float64(31.049571420424183), &#x27;episode_return_mean&#x27;: 0.8569658119658138, &#x27;env_to_module_sum_episodes_length_out&#x27;: np.float64(96.90217702112001), &#x27;num_env_steps_sampled_lifetime&#x27;: 394000, &#x27;episode_return_max&#x27;: 1.139222222222225, &#x27;env_reset_timer&#x27;: np.float64(3.173885230502492), &#x27;time_between_sampling&#x27;: np.float64(10.640472036977904), &#x27;num_env_steps_sampled_lifetime_throughput&#x27;: 47.91130618063368}</td><td>{&#x27;num_healthy_workers&#x27;: 8, &#x27;num_remote_worker_restarts&#x27;: 0}</td><td>{&#x27;default_policy&#x27;: {&#x27;module_train_batch_size_mean&#x27;: 128.0, &#x27;num_trainable_parameters&#x27;: 78599.0, &#x27;vf_explained_var&#x27;: np.float32(0.16097331), &#x27;vf_loss_unclipped&#x27;: np.float32(0.016424894), &#x27;curr_kl_coeff&#x2
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-04 13:00:00 到 2025-01-07 13:00:00 [repeated 8x across cluster]
# 🤩 step1181 平均reward为 -0.6620555555555552
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-03-06 13:00:00 到 2025-03-09 13:00:00 [repeated 8x across cluster]
# 🤩 step1651 平均reward为 -0.6176378205128203
# (SingleAgentEnvRunner pid=51626) ✅ 选中的时间段：2025-02-08 13:00:00 到 2025-02-11 13:00:00 [repeated 8x across cluster]
# 🤩 step2049 平均reward为 -0.5127542735042734
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-22 13:00:00 到 2025-02-25 13:00:00 [repeated 8x across cluster]
# 🤩 step2444 平均reward为 -0.31734508547008533
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-16 13:00:00 到 2025-02-19 13:00:00 [repeated 8x across cluster]
# 🤩 step2827 平均reward为 -0.22453311965811945
# (SingleAgentEnvRunner pid=51626) ✅ 选中的时间段：2025-01-25 13:00:00 到 2025-01-28 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51626) ✅ 选中的时间段：2025-03-09 13:00:00 到 2025-03-12 13:00:00 [repeated 8x across cluster]
# 🤩 step3259 平均reward为 -0.06508333333333322
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-03-11 13:00:00 到 2025-03-14 13:00:00 [repeated 8x across cluster]
# 🤩 step3655 平均reward为 -0.013746794871794737
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-01-08 13:00:00 到 2025-01-11 13:00:00 [repeated 8x across cluster]
# 🤩 step4056 平均reward为 0.1356762820512822
# (SingleAgentEnvRunner pid=51628) ✅ 选中的时间段：2024-12-26 13:00:00 到 2024-12-29 13:00:00 [repeated 8x across cluster]
# 🤩 step4458 平均reward为 0.11830769230769253
# (SingleAgentEnvRunner pid=51626) ✅ 选中的时间段：2025-02-24 13:00:00 到 2025-02-27 13:00:00 [repeated 8x across cluster]
# 🤩 step4855 平均reward为 0.15230448717948739
# (SingleAgentEnvRunner pid=51627) ✅ 选中的时间段：2024-12-29 13:00:00 到 2025-01-01 13:00:00 [repeated 8x across cluster]
# 🤩 step5260 平均reward为 0.2258151709401711
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-01-05 13:00:00 到 2025-01-08 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-02-01 13:00:00 到 2025-02-04 13:00:00 [repeated 8x across cluster]
# 🤩 step5678 平均reward为 0.23247756410256423
# (SingleAgentEnvRunner pid=51627) ✅ 选中的时间段：2025-02-25 13:00:00 到 2025-02-28 13:00:00 [repeated 8x across cluster]
# 🤩 step6054 平均reward为 0.25933653846153853
# (SingleAgentEnvRunner pid=51629) ✅ 选中的时间段：2025-02-17 13:00:00 到 2025-02-20 13:00:00 [repeated 8x across cluster]
# 🤩 step6436 平均reward为 0.26317948717948725
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-21 13:00:00 到 2025-02-24 13:00:00 [repeated 8x across cluster]
# 🤩 step6808 平均reward为 0.3244209401709402
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-01-09 13:00:00 到 2025-01-12 13:00:00 [repeated 8x across cluster]
# 🤩 step7213 平均reward为 0.3263867521367523
# (SingleAgentEnvRunner pid=51626) ✅ 选中的时间段：2025-01-09 13:00:00 到 2025-01-12 13:00:00 [repeated 8x across cluster]
# 🤩 step7587 平均reward为 0.28775534188034196
# (SingleAgentEnvRunner pid=51627) ✅ 选中的时间段：2025-01-03 13:00:00 到 2025-01-06 13:00:00 [repeated 8x across cluster]
# 🤩 step7959 平均reward为 0.367561965811966
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-03-07 13:00:00 到 2025-03-10 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-02-25 13:00:00 到 2025-02-28 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-04 13:00:00 到 2025-02-07 13:00:00 [repeated 7x across cluster]
# 🤩 step8390 平均reward为 0.449780982905983
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-09 13:00:00 到 2025-01-12 13:00:00
# (SingleAgentEnvRunner pid=51629) ✅ 选中的时间段：2025-03-12 13:00:00 到 2025-03-15 13:00:00
# 🤩 step8788 平均reward为 0.42560363247863264
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2024-12-31 13:00:00 到 2025-01-03 13:00:00 [repeated 7x across cluster]
# 🤩 step9183 平均reward为 0.4763044871794872
# (SingleAgentEnvRunner pid=51626) ✅ 选中的时间段：2025-01-08 13:00:00 到 2025-01-11 13:00:00 [repeated 8x across cluster]
# 🤩 step9555 平均reward为 0.47143696581196576
# (SingleAgentEnvRunner pid=51633) ✅ 选中的时间段：2025-02-09 13:00:00 到 2025-02-12 13:00:00 [repeated 8x across cluster]
# 🤩 step9944 平均reward为 0.5023269230769231
# (SingleAgentEnvRunner pid=51627) ✅ 选中的时间段：2024-12-22 13:00:00 到 2024-12-25 13:00:00 [repeated 8x across cluster]
# 🤩 step10319 平均reward为 0.5053141025641026
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-23 13:00:00 到 2025-01-26 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51629) ✅ 选中的时间段：2025-02-15 13:00:00 到 2025-02-18 13:00:00 [repeated 8x across cluster]
# 🤩 step10711 平均reward为 0.5990940170940179
# (SingleAgentEnvRunner pid=51628) ✅ 选中的时间段：2025-01-04 13:00:00 到 2025-01-07 13:00:00 [repeated 8x across cluster]
# 🤩 step11104 平均reward为 0.5463173076923081
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-25 13:00:00 到 2025-01-28 13:00:00 [repeated 8x across cluster]
# 🤩 step11482 平均reward为 0.5300320512820516
# (SingleAgentEnvRunner pid=51628) ✅ 选中的时间段：2025-03-09 13:00:00 到 2025-03-12 13:00:00 [repeated 8x across cluster]
# 🤩 step11866 平均reward为 0.6142916666666667
# (SingleAgentEnvRunner pid=51627) ✅ 选中的时间段：2025-01-20 13:00:00 到 2025-01-23 13:00:00 [repeated 8x across cluster]
# 🤩 step12252 平均reward为 0.584625
# (SingleAgentEnvRunner pid=51627) ✅ 选中的时间段：2025-01-12 13:00:00 到 2025-01-15 13:00:00 [repeated 8x across cluster]
# 🤩 step12635 平均reward为 0.48722542735042723
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2024-12-29 13:00:00 到 2025-01-01 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-03-07 13:00:00 到 2025-03-10 13:00:00 [repeated 8x across cluster]
# 🤩 step13026 平均reward为 0.5157724358974363
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-24 13:00:00 到 2025-01-27 13:00:00 [repeated 8x across cluster]
# 🤩 step13413 平均reward为 0.6013450854700861
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-01-06 13:00:00 到 2025-01-09 13:00:00 [repeated 8x across cluster]
# 🤩 step13788 平均reward为 0.5799754273504278
# (SingleAgentEnvRunner pid=51628) ✅ 选中的时间段：2025-01-07 13:00:00 到 2025-01-10 13:00:00 [repeated 8x across cluster]
# 🤩 step14179 平均reward为 0.5567083333333332
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-18 13:00:00 到 2025-02-21 13:00:00 [repeated 8x across cluster]
# 🤩 step14602 平均reward为 0.6937083333333336
# (SingleAgentEnvRunner pid=51629) ✅ 选中的时间段：2025-01-29 13:00:00 到 2025-02-01 13:00:00 [repeated 8x across cluster]
# 🤩 step15081 平均reward为 0.6746805555555555
# (SingleAgentEnvRunner pid=51628) ✅ 选中的时间段：2025-01-11 13:00:00 到 2025-01-14 13:00:00 [repeated 8x across cluster]
# 🤩 step15543 平均reward为 0.7353675213675218
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-02-26 13:00:00 到 2025-03-01 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-02-22 13:00:00 到 2025-02-25 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-03 13:00:00 到 2025-01-06 13:00:00 [repeated 4x across cluster]
# 🤩 step16074 平均reward为 0.6976431623931637
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-03-04 13:00:00 到 2025-03-07 13:00:00 [repeated 4x across cluster]
# (SingleAgentEnvRunner pid=51626) ✅ 选中的时间段：2025-01-09 13:00:00 到 2025-01-12 13:00:00 [repeated 3x across cluster]
# 🤩 step16565 平均reward为 0.6837692307692318
# (SingleAgentEnvRunner pid=51627) ✅ 选中的时间段：2025-03-09 13:00:00 到 2025-03-12 13:00:00 [repeated 5x across cluster]
# 🤩 step17082 平均reward为 0.6531260683760688
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-02-20 13:00:00 到 2025-02-23 13:00:00 [repeated 8x across cluster]
# 🤩 step17590 平均reward为 0.699059829059829
# (SingleAgentEnvRunner pid=51628) ✅ 选中的时间段：2025-03-05 13:00:00 到 2025-03-08 13:00:00 [repeated 8x across cluster]
# 🤩 step18093 平均reward为 0.6858237179487181
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-01-05 13:00:00 到 2025-01-08 13:00:00 [repeated 8x across cluster]
# 🤩 step18484 平均reward为 0.721754273504274
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-02-22 13:00:00 到 2025-02-25 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51629) ✅ 选中的时间段：2024-12-30 13:00:00 到 2025-01-02 13:00:00 [repeated 8x across cluster]
# 🤩 step18887 平均reward为 0.6949358974358986
# (SingleAgentEnvRunner pid=51633) ✅ 选中的时间段：2025-02-28 13:00:00 到 2025-03-03 13:00:00 [repeated 8x across cluster]
# 🤩 step19296 平均reward为 0.7756100427350445
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-02-01 13:00:00 到 2025-02-04 13:00:00 [repeated 8x across cluster]
# 🤩 step19694 平均reward为 0.7722286324786337
# (SingleAgentEnvRunner pid=51628) ✅ 选中的时间段：2025-01-01 13:00:00 到 2025-01-04 13:00:00 [repeated 8x across cluster]
# 🤩 step20110 平均reward为 0.7421207264957268
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-03-02 13:00:00 到 2025-03-05 13:00:00 [repeated 8x across cluster]
# 🤩 step20531 平均reward为 0.6865245726495727
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-01 13:00:00 到 2025-01-04 13:00:00 [repeated 8x across cluster]
# 🤩 step20938 平均reward为 0.7404433760683762
# (SingleAgentEnvRunner pid=51633) ✅ 选中的时间段：2025-01-14 13:00:00 到 2025-01-17 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2024-12-22 13:00:00 到 2024-12-25 13:00:00 [repeated 8x across cluster]
# 🤩 step21398 平均reward为 0.682892094017095
# (SingleAgentEnvRunner pid=51627) ✅ 选中的时间段：2025-01-03 13:00:00 到 2025-01-06 13:00:00 [repeated 8x across cluster]
# 🤩 step21817 平均reward为 0.7646346153846173
# (SingleAgentEnvRunner pid=51629) ✅ 选中的时间段：2024-12-27 13:00:00 到 2024-12-30 13:00:00 [repeated 8x across cluster]
# 🤩 step22211 平均reward为 0.7550053418803435
# (SingleAgentEnvRunner pid=51627) ✅ 选中的时间段：2025-02-03 13:00:00 到 2025-02-06 13:00:00 [repeated 8x across cluster]
# 🤩 step22607 平均reward为 0.7515480769230778
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-15 13:00:00 到 2025-01-18 13:00:00 [repeated 8x across cluster]
# 🤩 step23007 平均reward为 0.7740042735042737
# (SingleAgentEnvRunner pid=51633) ✅ 选中的时间段：2025-01-15 13:00:00 到 2025-01-18 13:00:00 [repeated 8x across cluster]
# 🤩 step23415 平均reward为 0.79953311965812
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-02-07 13:00:00 到 2025-02-10 13:00:00 [repeated 8x across cluster]
# 🤩 step23833 平均reward为 0.7803119658119665
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-02-18 13:00:00 到 2025-02-21 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-01-17 13:00:00 到 2025-01-20 13:00:00 [repeated 8x across cluster]
# 🤩 step24292 平均reward为 0.7463782051282071
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-01-30 13:00:00 到 2025-02-02 13:00:00 [repeated 8x across cluster]
# 🤩 step24731 平均reward为 0.7300822649572665
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-01-21 13:00:00 到 2025-01-24 13:00:00 [repeated 8x across cluster]
# 🤩 step25159 平均reward为 0.695117521367522
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-01-31 13:00:00 到 2025-02-03 13:00:00 [repeated 8x across cluster]
# 🤩 step25574 平均reward为 0.6746570512820514
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-02-07 13:00:00 到 2025-02-10 13:00:00 [repeated 8x across cluster]
# 🤩 step25962 平均reward为 0.6569123931623932
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-03-09 13:00:00 到 2025-03-12 13:00:00 [repeated 8x across cluster]
# 🤩 step26403 平均reward为 0.6743130341880346
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-03-08 13:00:00 到 2025-03-11 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-25 13:00:00 到 2025-02-28 13:00:00 [repeated 8x across cluster]
# 🤩 step26846 平均reward为 0.8836506410256433
# (SingleAgentEnvRunner pid=51633) ✅ 选中的时间段：2025-01-04 13:00:00 到 2025-01-07 13:00:00 [repeated 8x across cluster]
# 🤩 step27259 平均reward为 0.8268771367521388
# (SingleAgentEnvRunner pid=51626) ✅ 选中的时间段：2025-03-07 13:00:00 到 2025-03-10 13:00:00 [repeated 8x across cluster]
# 🤩 step27662 平均reward为 0.7912126068376085
# (SingleAgentEnvRunner pid=51633) ✅ 选中的时间段：2025-01-22 13:00:00 到 2025-01-25 13:00:00 [repeated 8x across cluster]
# 🤩 step28072 平均reward为 0.7815106837606843
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2024-12-23 13:00:00 到 2024-12-26 13:00:00 [repeated 8x across cluster]
# 🤩 step28481 平均reward为 0.7160202991452991
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-09 13:00:00 到 2025-01-12 13:00:00 [repeated 8x across cluster]
# 🤩 step28898 平均reward为 0.7154989316239319
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-03-08 13:00:00 到 2025-03-11 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51628) ✅ 选中的时间段：2024-12-27 13:00:00 到 2024-12-30 13:00:00 [repeated 8x across cluster]
# 🤩 step29304 平均reward为 0.7600705128205141
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-01-21 13:00:00 到 2025-01-24 13:00:00 [repeated 8x across cluster]
# 🤩 step29685 平均reward为 0.8643076923076946
# (SingleAgentEnvRunner pid=51633) ✅ 选中的时间段：2025-02-24 13:00:00 到 2025-02-27 13:00:00 [repeated 8x across cluster]
# 🤩 step30093 平均reward为 0.8014978632478653
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-02-04 13:00:00 到 2025-02-07 13:00:00 [repeated 8x across cluster]
# 🤩 step30509 平均reward为 0.746621794871796
# (SingleAgentEnvRunner pid=51627) ✅ 选中的时间段：2025-02-10 13:00:00 到 2025-02-13 13:00:00 [repeated 8x across cluster]
# 🤩 step30918 平均reward为 0.7314743589743593
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-01-27 13:00:00 到 2025-01-30 13:00:00 [repeated 8x across cluster]
# 🤩 step31317 平均reward为 0.7285363247863247
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-01-24 13:00:00 到 2025-01-27 13:00:00 [repeated 8x across cluster]
# 🤩 step31717 平均reward为 0.7539401709401712
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-14 13:00:00 到 2025-01-17 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51626) ✅ 选中的时间段：2025-03-12 13:00:00 到 2025-03-15 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51633) ✅ 选中的时间段：2025-01-09 13:00:00 到 2025-01-12 13:00:00 [repeated 5x across cluster]
# 🤩 step32171 平均reward为 0.8331837606837627
# (SingleAgentEnvRunner pid=51629) ✅ 选中的时间段：2025-01-04 13:00:00 到 2025-01-07 13:00:00 [repeated 3x across cluster]
# 🤩 step32518 平均reward为 0.7897040598290617
# (SingleAgentEnvRunner pid=51626) ✅ 选中的时间段：2025-03-06 13:00:00 到 2025-03-09 13:00:00 [repeated 8x across cluster]
# 🤩 step32966 平均reward为 0.7598044871794885
# (SingleAgentEnvRunner pid=51628) ✅ 选中的时间段：2025-01-04 13:00:00 到 2025-01-07 13:00:00 [repeated 8x across cluster]
# 🤩 step33348 平均reward为 0.749922008547009
# (SingleAgentEnvRunner pid=51629) ✅ 选中的时间段：2025-02-16 13:00:00 到 2025-02-19 13:00:00 [repeated 8x across cluster]
# 🤩 step33747 平均reward为 0.7510608974358974
# (SingleAgentEnvRunner pid=51629) ✅ 选中的时间段：2025-03-11 13:00:00 到 2025-03-14 13:00:00 [repeated 8x across cluster]
# 🤩 step34166 平均reward为 0.7558803418803424
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-03-07 13:00:00 到 2025-03-10 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51628) ✅ 选中的时间段：2025-03-12 13:00:00 到 2025-03-15 13:00:00 [repeated 8x across cluster]
# 🤩 step34576 平均reward为 0.8005309829059846
# (SingleAgentEnvRunner pid=51627) ✅ 选中的时间段：2025-02-06 13:00:00 到 2025-02-09 13:00:00 [repeated 8x across cluster]
# 🤩 step34978 平均reward为 0.8189561965811987
# (SingleAgentEnvRunner pid=51629) ✅ 选中的时间段：2025-02-07 13:00:00 到 2025-02-10 13:00:00 [repeated 8x across cluster]
# 🤩 step35357 平均reward为 0.8332061965811985
# (SingleAgentEnvRunner pid=51627) ✅ 选中的时间段：2025-02-11 13:00:00 到 2025-02-14 13:00:00 [repeated 8x across cluster]
# 🤩 step35783 平均reward为 0.8339903846153855
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-03-02 13:00:00 到 2025-03-05 13:00:00 [repeated 8x across cluster]
# 🤩 step36174 平均reward为 0.7904925213675218
# (SingleAgentEnvRunner pid=51627) ✅ 选中的时间段：2025-02-28 13:00:00 到 2025-03-03 13:00:00 [repeated 8x across cluster]
# 🤩 step36565 平均reward为 0.8302628205128209
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-27 13:00:00 到 2025-01-30 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-25 13:00:00 到 2025-01-28 13:00:00 [repeated 8x across cluster]
# 🤩 step36974 平均reward为 0.8559615384615402
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-19 13:00:00 到 2025-01-22 13:00:00 [repeated 8x across cluster]
# 🤩 step37375 平均reward为 0.8832500000000023
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-01-29 13:00:00 到 2025-02-01 13:00:00 [repeated 8x across cluster]
# 🤩 step37782 平均reward为 0.7899262820512838
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-03 13:00:00 到 2025-02-06 13:00:00 [repeated 8x across cluster]
# 🤩 step38157 平均reward为 0.7609829059829069
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-02-02 13:00:00 到 2025-02-05 13:00:00 [repeated 8x across cluster]
# 🤩 step38525 平均reward为 0.7951250000000006
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-02-18 13:00:00 到 2025-02-21 13:00:00 [repeated 8x across cluster]
# 🤩 step38895 平均reward为 0.8661645299145302
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-02-21 13:00:00 到 2025-02-24 13:00:00 [repeated 8x across cluster]
# 🤩 step39276 平均reward为 0.836952991452992
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2024-12-24 13:00:00 到 2024-12-27 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-09 13:00:00 到 2025-02-12 13:00:00 [repeated 8x across cluster]
# 🤩 step39685 平均reward为 0.8056292735042755
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-03-02 13:00:00 到 2025-03-05 13:00:00 [repeated 8x across cluster]
# 🤩 step40064 平均reward为 0.7704123931623948
# (SingleAgentEnvRunner pid=51633) ✅ 选中的时间段：2024-12-25 13:00:00 到 2024-12-28 13:00:00 [repeated 8x across cluster]
# 🤩 step40477 平均reward为 0.80984294871795
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-02-10 13:00:00 到 2025-02-13 13:00:00 [repeated 8x across cluster]
# 🤩 step40880 平均reward为 0.8817638888888896
# (SingleAgentEnvRunner pid=51629) ✅ 选中的时间段：2025-02-03 13:00:00 到 2025-02-06 13:00:00 [repeated 8x across cluster]
# 🤩 step41280 平均reward为 0.8620405982905989
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-01-26 13:00:00 到 2025-01-29 13:00:00 [repeated 8x across cluster]
# 🤩 step41676 平均reward为 0.8136260683760685
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-02 13:00:00 到 2025-01-05 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-31 13:00:00 到 2025-02-03 13:00:00 [repeated 8x across cluster]
# 🤩 step42116 平均reward为 0.7289529914529926
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2024-12-22 13:00:00 到 2024-12-25 13:00:00 [repeated 8x across cluster]
# 🤩 step42523 平均reward为 0.7557222222222238
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2024-12-31 13:00:00 到 2025-01-03 13:00:00 [repeated 8x across cluster]
# 🤩 step42926 平均reward为 0.7528814102564116
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2024-12-24 13:00:00 到 2024-12-27 13:00:00 [repeated 8x across cluster]
# 🤩 step43316 平均reward为 0.7315416666666672
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-15 13:00:00 到 2025-02-18 13:00:00 [repeated 8x across cluster]
# 🤩 step43725 平均reward为 0.8334027777777782
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2024-12-29 13:00:00 到 2025-01-01 13:00:00 [repeated 8x across cluster]
# 🤩 step44133 平均reward为 0.9060641025641032
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-05 13:00:00 到 2025-01-08 13:00:00 [repeated 8x across cluster]
# 🤩 step44570 平均reward为 0.7268333333333344
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-02 13:00:00 到 2025-01-05 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-03-09 13:00:00 到 2025-03-12 13:00:00 [repeated 8x across cluster]
# 🤩 step44994 平均reward为 0.8191335470085493
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-03-05 13:00:00 到 2025-03-08 13:00:00 [repeated 8x across cluster]
# 🤩 step45420 平均reward为 0.9323023504273529
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-22 13:00:00 到 2025-01-25 13:00:00 [repeated 8x across cluster]
# 🤩 step45858 平均reward为 0.8989647435897451
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-09 13:00:00 到 2025-02-12 13:00:00 [repeated 8x across cluster]
# 🤩 step46229 平均reward为 0.8723376068376075
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-10 13:00:00 到 2025-01-13 13:00:00 [repeated 8x across cluster]
# 🤩 step46617 平均reward为 0.8848344017094021
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-07 13:00:00 到 2025-01-10 13:00:00 [repeated 8x across cluster]
# 🤩 step46997 平均reward为 0.9816944444444456
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2024-12-25 13:00:00 到 2024-12-28 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-03-12 13:00:00 到 2025-03-15 13:00:00 [repeated 8x across cluster]
# 🤩 step47437 平均reward为 0.7648461538461556
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-01-15 13:00:00 到 2025-01-18 13:00:00 [repeated 8x across cluster]
# 🤩 step47828 平均reward为 0.8214038461538483
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-13 13:00:00 到 2025-02-16 13:00:00 [repeated 8x across cluster]
# 🤩 step48228 平均reward为 0.8619465811965827
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-21 13:00:00 到 2025-02-24 13:00:00 [repeated 8x across cluster]
# 🤩 step48610 平均reward为 0.9198792735042741
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-02-04 13:00:00 到 2025-02-07 13:00:00 [repeated 8x across cluster]
# 🤩 step49005 平均reward为 0.9162158119658125
# (SingleAgentEnvRunner pid=51626) ✅ 选中的时间段：2025-01-11 13:00:00 到 2025-01-14 13:00:00 [repeated 8x across cluster]
# 🤩 step49387 平均reward为 0.8485341880341888
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-02-27 13:00:00 到 2025-03-02 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51626) ✅ 选中的时间段：2025-01-01 13:00:00 到 2025-01-04 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51627) ✅ 选中的时间段：2025-02-12 13:00:00 到 2025-02-15 13:00:00 [repeated 7x across cluster]
# 🤩 step49879 平均reward为 0.8875117521367546
# (SingleAgentEnvRunner pid=51626) ✅ 选中的时间段：2025-02-21 13:00:00 到 2025-02-24 13:00:00
# (SingleAgentEnvRunner pid=51627) ✅ 选中的时间段：2025-01-25 13:00:00 到 2025-01-28 13:00:00
# 🤩 step50308 平均reward为 0.8985630341880367
# (SingleAgentEnvRunner pid=51626) ✅ 选中的时间段：2025-02-23 13:00:00 到 2025-02-26 13:00:00 [repeated 7x across cluster]
# 🤩 step50727 平均reward为 0.9009220085470109
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-07 13:00:00 到 2025-02-10 13:00:00 [repeated 8x across cluster]
# 🤩 step51149 平均reward为 0.8569764957264966
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-28 13:00:00 到 2025-01-31 13:00:00 [repeated 8x across cluster]
# 🤩 step51550 平均reward为 0.8531100427350432
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-19 13:00:00 到 2025-02-22 13:00:00 [repeated 8x across cluster]
# 🤩 step51926 平均reward为 0.8252425213675215
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-09 13:00:00 到 2025-01-12 13:00:00 [repeated 8x across cluster]
# 🤩 step52295 平均reward为 0.8477820512820521
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-04 13:00:00 到 2025-01-07 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-17 13:00:00 到 2025-02-20 13:00:00 [repeated 8x across cluster]
# 🤩 step52700 平均reward为 0.7557745726495745
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-05 13:00:00 到 2025-01-08 13:00:00 [repeated 8x across cluster]
# 🤩 step53025 平均reward为 0.7599615384615404
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-10 13:00:00 到 2025-02-13 13:00:00 [repeated 8x across cluster]
# 🤩 step53403 平均reward为 0.7496506410256422
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2024-12-28 13:00:00 到 2024-12-31 13:00:00 [repeated 8x across cluster]
# 🤩 step53767 平均reward为 0.7862403846153847
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-02-24 13:00:00 到 2025-02-27 13:00:00 [repeated 8x across cluster]
# 🤩 step54116 平均reward为 0.8486730769230769
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-14 13:00:00 到 2025-02-17 13:00:00 [repeated 8x across cluster]
# 🤩 step54474 平均reward为 0.8527382478632486
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-22 13:00:00 到 2025-02-25 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-03-06 13:00:00 到 2025-03-09 13:00:00 [repeated 8x across cluster]
# 🤩 step54859 平均reward为 0.9072243589743617
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-08 13:00:00 到 2025-02-11 13:00:00 [repeated 8x across cluster]
# 🤩 step55208 平均reward为 0.8336549145299166
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-02-08 13:00:00 到 2025-02-11 13:00:00 [repeated 8x across cluster]
# 🤩 step55582 平均reward为 0.8908888888888907
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-24 13:00:00 到 2025-02-27 13:00:00 [repeated 8x across cluster]
# 🤩 step55936 平均reward为 0.9741303418803432
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-03-02 13:00:00 到 2025-03-05 13:00:00 [repeated 8x across cluster]
# 🤩 step56329 平均reward为 0.8867991452991456
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-02-22 13:00:00 到 2025-02-25 13:00:00 [repeated 8x across cluster]
# 🤩 step56703 平均reward为 0.7963087606837606
# (SingleAgentEnvRunner pid=51627) ✅ 选中的时间段：2025-02-26 13:00:00 到 2025-03-01 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-27 13:00:00 到 2025-01-30 13:00:00 [repeated 8x across cluster]
# 🤩 step57107 平均reward为 0.931158119658122
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-03-02 13:00:00 到 2025-03-05 13:00:00 [repeated 8x across cluster]
# 🤩 step57485 平均reward为 0.8390470085470105
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-01-24 13:00:00 到 2025-01-27 13:00:00 [repeated 8x across cluster]
# 🤩 step57875 平均reward为 0.8966346153846173
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-13 13:00:00 到 2025-01-16 13:00:00 [repeated 8x across cluster]
# 🤩 step58253 平均reward为 0.9045950854700867
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-02 13:00:00 到 2025-01-05 13:00:00 [repeated 8x across cluster]
# 🤩 step58615 平均reward为 0.8310074786324796
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-26 13:00:00 到 2025-03-01 13:00:00 [repeated 8x across cluster]
# 🤩 step58974 平均reward为 0.8076666666666669
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-11 13:00:00 到 2025-02-14 13:00:00 [repeated 8x across cluster]
# 🤩 step59325 平均reward为 0.88230982905983
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2024-12-25 13:00:00 到 2024-12-28 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51628)
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-01-16 13:00:00 到 2025-01-19 13:00:00 [repeated 8x across cluster]
# 🤩 step59744 平均reward为 0.8426623931623956
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-21 13:00:00 到 2025-01-24 13:00:00 [repeated 8x across cluster]
# 🤩 step60117 平均reward为 0.9040608974358997
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-01-27 13:00:00 到 2025-01-30 13:00:00 [repeated 8x across cluster]
# 🤩 step60520 平均reward为 0.8301720085470099
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-02-23 13:00:00 到 2025-02-26 13:00:00 [repeated 8x across cluster]
# 🤩 step60894 平均reward为 0.8472927350427356
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-01-14 13:00:00 到 2025-01-17 13:00:00 [repeated 8x across cluster]
# 🤩 step61280 平均reward为 0.899425213675214
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-01-24 13:00:00 到 2025-01-27 13:00:00 [repeated 8x across cluster]
# 🤩 step61666 平均reward为 0.8864455128205134
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-02-23 13:00:00 到 2025-02-26 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-09 13:00:00 到 2025-02-12 13:00:00 [repeated 8x across cluster]
# 🤩 step62068 平均reward为 0.921473290598293
# (SingleAgentEnvRunner pid=51628) ✅ 选中的时间段：2025-01-30 13:00:00 到 2025-02-02 13:00:00 [repeated 8x across cluster]
# 🤩 step62444 平均reward为 0.8653621794871819
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-01-15 13:00:00 到 2025-01-18 13:00:00 [repeated 8x across cluster]
# 🤩 step62813 平均reward为 0.8584273504273521
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-27 13:00:00 到 2025-03-02 13:00:00 [repeated 8x across cluster]
# 🤩 step63193 平均reward为 0.9651549145299154
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-01-31 13:00:00 到 2025-02-03 13:00:00 [repeated 8x across cluster]
# 🤩 step63577 平均reward为 0.9641047008547012
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-26 13:00:00 到 2025-01-29 13:00:00 [repeated 8x across cluster]
# 🤩 step63969 平均reward为 0.9225876068376073
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-02-25 13:00:00 到 2025-02-28 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51628) ✅ 选中的时间段：2025-01-13 13:00:00 到 2025-01-16 13:00:00 [repeated 8x across cluster]
# 🤩 step64356 平均reward为 0.766947649572651
# (SingleAgentEnvRunner pid=51628) ✅ 选中的时间段：2025-02-23 13:00:00 到 2025-02-26 13:00:00 [repeated 8x across cluster]
# 🤩 step64773 平均reward为 0.8075940170940192
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2024-12-23 13:00:00 到 2024-12-26 13:00:00 [repeated 8x across cluster]
# 🤩 step65161 平均reward为 0.8002275641025659
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-01-29 13:00:00 到 2025-02-01 13:00:00 [repeated 8x across cluster]
# 🤩 step65560 平均reward为 0.843232905982907
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-26 13:00:00 到 2025-03-01 13:00:00 [repeated 8x across cluster]
# 🤩 step65966 平均reward为 0.8799326923076928
# (SingleAgentEnvRunner pid=51628) ✅ 选中的时间段：2025-03-05 13:00:00 到 2025-03-08 13:00:00 [repeated 8x across cluster]
# 🤩 step66374 平均reward为 0.8333824786324789
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2024-12-26 13:00:00 到 2024-12-29 13:00:00 [repeated 8x across cluster]
# 🤩 step66782 平均reward为 0.9180982905982916
# (SingleAgentEnvRunner pid=51628) ✅ 选中的时间段：2025-02-04 13:00:00 到 2025-02-07 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-18 13:00:00 到 2025-01-21 13:00:00 [repeated 8x across cluster]
# 🤩 step67189 平均reward为 0.8566613247863272
# (SingleAgentEnvRunner pid=51626) ✅ 选中的时间段：2025-01-30 13:00:00 到 2025-02-02 13:00:00 [repeated 8x across cluster]
# 🤩 step67608 平均reward为 0.8876891025641049
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-02-18 13:00:00 到 2025-02-21 13:00:00 [repeated 8x across cluster]
# 🤩 step68012 平均reward为 0.8929914529914545
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-01-27 13:00:00 到 2025-01-30 13:00:00 [repeated 8x across cluster]
# 🤩 step68402 平均reward为 0.9064220085470089
# (SingleAgentEnvRunner pid=51628) ✅ 选中的时间段：2025-01-26 13:00:00 到 2025-01-29 13:00:00 [repeated 8x across cluster]
# 🤩 step68771 平均reward为 0.7843899572649572
# (SingleAgentEnvRunner pid=51629) ✅ 选中的时间段：2025-01-24 13:00:00 到 2025-01-27 13:00:00 [repeated 8x across cluster]
# 🤩 step69156 平均reward为 0.7064358974358976
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-07 13:00:00 到 2025-01-10 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51626) ✅ 选中的时间段：2025-01-29 13:00:00 到 2025-02-01 13:00:00 [repeated 8x across cluster]
# 🤩 step69567 平均reward为 0.8716388888888912
# (SingleAgentEnvRunner pid=51629) ✅ 选中的时间段：2025-01-22 13:00:00 到 2025-01-25 13:00:00 [repeated 8x across cluster]
# 🤩 step69951 平均reward为 0.8275192307692326
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-15 13:00:00 到 2025-02-18 13:00:00 [repeated 8x across cluster]
# 🤩 step70347 平均reward为 0.793036324786326
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-01-09 13:00:00 到 2025-01-12 13:00:00 [repeated 8x across cluster]
# 🤩 step70743 平均reward为 0.8492200854700859
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-01-28 13:00:00 到 2025-01-31 13:00:00 [repeated 8x across cluster]
# 🤩 step71129 平均reward为 0.8617959401709403
# (SingleAgentEnvRunner pid=51627) ✅ 选中的时间段：2025-02-16 13:00:00 到 2025-02-19 13:00:00 [repeated 8x across cluster]
# 🤩 step71519 平均reward为 0.854069444444445
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-21 13:00:00 到 2025-02-24 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51633) ✅ 选中的时间段：2025-02-14 13:00:00 到 2025-02-17 13:00:00 [repeated 8x across cluster]
# 🤩 step71910 平均reward为 0.8565416666666683
# (SingleAgentEnvRunner pid=51628) ✅ 选中的时间段：2025-02-24 13:00:00 到 2025-02-27 13:00:00 [repeated 8x across cluster]
# 🤩 step72265 平均reward为 0.8794123931623956
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-02-21 13:00:00 到 2025-02-24 13:00:00 [repeated 8x across cluster]
# 🤩 step72629 平均reward为 0.9086805555555575
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-02-26 13:00:00 到 2025-03-01 13:00:00 [repeated 8x across cluster]
# 🤩 step72996 平均reward为 0.9979380341880356
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-02-08 13:00:00 到 2025-02-11 13:00:00 [repeated 8x across cluster]
# 🤩 step73378 平均reward为 0.985536324786326
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-03-10 13:00:00 到 2025-03-13 13:00:00 [repeated 8x across cluster]
# 🤩 step73824 平均reward为 0.9093066239316246
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2024-12-28 13:00:00 到 2024-12-31 13:00:00 [repeated 8x across cluster]
# 🤩 step74225 平均reward为 0.9191912393162399
# (SingleAgentEnvRunner pid=51623) ✅ 选中的时间段：2025-01-25 13:00:00 到 2025-01-28 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51633) ✅ 选中的时间段：2025-02-17 13:00:00 到 2025-02-20 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-02-26 13:00:00 到 2025-03-01 13:00:00 [repeated 7x across cluster]
# 🤩 step74661 平均reward为 0.9023205128205151
# (SingleAgentEnvRunner pid=51626) ✅ 选中的时间段：2025-01-25 13:00:00 到 2025-01-28 13:00:00
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-01-08 13:00:00 到 2025-01-11 13:00:00
# 🤩 step75053 平均reward为 0.9301613247863271
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-02-18 13:00:00 到 2025-02-21 13:00:00 [repeated 7x across cluster]
# 🤩 step75390 平均reward为 0.8137222222222233
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-02-01 13:00:00 到 2025-02-04 13:00:00 [repeated 8x across cluster]
# 🤩 step75796 平均reward为 0.837282051282052
# (SingleAgentEnvRunner pid=51628) ✅ 选中的时间段：2025-01-28 13:00:00 到 2025-01-31 13:00:00 [repeated 8x across cluster]
# 🤩 step76185 平均reward为 0.8519604700854704
# (SingleAgentEnvRunner pid=51628) ✅ 选中的时间段：2025-01-08 13:00:00 到 2025-01-11 13:00:00 [repeated 8x across cluster]
# 🤩 step76570 平均reward为 0.925538461538462
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-01-08 13:00:00 到 2025-01-11 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51629) ✅ 选中的时间段：2025-01-02 13:00:00 到 2025-01-05 13:00:00 [repeated 8x across cluster]
# 🤩 step76949 平均reward为 0.8210502136752154
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-01-12 13:00:00 到 2025-01-15 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51626) ✅ 选中的时间段：2025-02-08 13:00:00 到 2025-02-11 13:00:00 [repeated 7x across cluster]
# 🤩 step77345 平均reward为 0.8558119658119678
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-01-13 13:00:00 到 2025-01-16 13:00:00
# (SingleAgentEnvRunner pid=51625) ✅ 选中的时间段：2025-01-06 13:00:00 到 2025-01-09 13:00:00
# 🤩 step77712 平均reward为 0.8671752136752157
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-03-05 13:00:00 到 2025-03-08 13:00:00 [repeated 7x across cluster]
# 🤩 step78083 平均reward为 0.7813130341880348
# (SingleAgentEnvRunner pid=51628) ✅ 选中的时间段：2025-03-05 13:00:00 到 2025-03-08 13:00:00 [repeated 8x across cluster]
# 🤩 step78442 平均reward为 0.8555993589743595
# (SingleAgentEnvRunner pid=51626) ✅ 选中的时间段：2024-12-28 13:00:00 到 2024-12-31 13:00:00 [repeated 8x across cluster]
# 🤩 step78809 平均reward为 0.9118376068376074
# (SingleAgentEnvRunner pid=51629) ✅ 选中的时间段：2025-02-28 13:00:00 到 2025-03-03 13:00:00 [repeated 8x across cluster]
# (SingleAgentEnvRunner pid=51624) ✅ 选中的时间段：2025-03-04 13:00:00 到 2025-03-07 13:00:00 [repeated 8x across cluster]
# 🤩 step79219 平均reward为 0.8569658119658138
# 2025-05-11 08:09:27,631	WARNING tune.py:219 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.
# 2025-05-11 08:09:27,659	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/home/ypp/ray_results/PPO_2025-05-11_05-54-47' in 0.0216s.
# (SingleAgentEnvRunner pid=51629) ✅ 选中的时间段：2025-03-06 13:00:00 到 2025-03-09 13:00:00 [repeated 8x across cluster]
# 2025-05-11 08:09:37,820	INFO tune.py:1041 -- Total run time: 8090.07 seconds (8079.87 seconds for the tuning loop).
# 2025-05-11 08:09:37,822	WARNING tune.py:1056 -- Experiment has been interrupted, but the most recent state was saved.
# Resume experiment with: Tuner.restore(path="/home/ypp/ray_results/PPO_2025-05-11_05-54-47", trainable=...)
# (SingleAgentEnvRunner pid=51628) ✅ 选中的时间段：2024-12-23 13:00:00 到 2024-12-26 13:00:00
# (PPO pid=51560) 2025-05-11 05:55:18,473	WARNING deprecation.py:50 -- DeprecationWarning: `RLModule(config=[RLModuleConfig object])` has been deprecated. Use `RLModule(observation_space=.., action_space=.., inference_only=.., model_config=.., catalog_class=..)` instead. This will raise an error in the future! [repeated 8x across cluster]
# Best result: Result(
#   metrics={'timers': {'training_iteration': 41.298672448832974, 'restore_env_runners': 2.6855829515909364e-05, 'training_step': 41.29812595009544, 'env_runner_sampling_timer': 31.77328559238279, 'learner_update_timer': 9.516576693775553, 'synch_weights': 0.00715059553037976, 'synch_env_connectors': 0.008990069688833084}, 'env_runners': {'module_episode_returns_mean': {'default_policy': 0.8569658119658138}, 'env_to_module_connector': {'timers': {'connectors': {'add_time_dim_to_batch_and_zero_pad': np.float64(3.815440857907775e-05), 'numpy_to_tensor': np.float64(0.00016533352364738442), 'add_states_from_episodes_to_batch': np.float64(1.9489993799315894e-05), 'batch_individual_items': np.float64(9.423757505503698e-05), 'add_observations_from_episodes_to_batch': np.float64(3.908466598084334e-05)}}, 'connector_pipeline_timer': np.float64(0.0005975134642284587)}, 'num_module_steps_sampled': {'default_policy': 2000}, 'num_episodes': 16, 'env_to_module_sum_episodes_length_in': np.float64(96.90217702112001), 'num_env_steps_sampled': 2000, 'num_agent_steps_sampled': {'default_agent': 2000}, 'rlmodule_inference_timer': np.float64(0.0005520652274458788), 'episode_len_max': 216, 'agent_episode_returns_mean': {'default_agent': 0.8569658119658138}, 'episode_len_mean': 216.0, 'module_to_env_connector': {'timers': {'connectors': {'un_batch_to_individual_items': np.float64(6.867735272668181e-05), 'remove_single_ts_time_rank_from_batch': np.float64(7.802360381821858e-06), 'listify_data_for_vector_env': np.float64(0.00013480365940378062), 'get_actions': np.float64(0.000706124885082818), 'tensor_to_numpy': np.float64(0.00022647541676187497), 'normalize_and_clip_actions': np.float64(0.00011949663555757771)}}, 'connector_pipeline_timer': np.float64(0.0015778870152950459)}, 'num_module_steps_sampled_lifetime': {'default_policy': 394000}, 'env_step_timer': np.float64(0.1092624012128406), 'episode_duration_sec_mean': 21.992496384163204, 'num_episodes_lifetime': 1824, 'episode_return_min': 0.6165555555555567, 'weights_seq_no': 196.0, 'episode_len_min': 216, 'num_agent_steps_sampled_lifetime': {'default_agent': 394000}, 'sample': np.float64(31.049571420424183), 'episode_return_mean': 0.8569658119658138, 'env_to_module_sum_episodes_length_out': np.float64(96.90217702112001), 'num_env_steps_sampled_lifetime': 394000, 'episode_return_max': 1.139222222222225, 'env_reset_timer': np.float64(3.173885230502492), 'time_between_sampling': np.float64(10.640472036977904), 'num_env_steps_sampled_lifetime_throughput': 47.91130618063368}, 'learners': {'default_policy': {'module_train_batch_size_mean': 128.0, 'num_trainable_parameters': 78599.0, 'vf_explained_var': np.float32(0.16097331), 'vf_loss_unclipped': np.float32(0.016424894), 'curr_kl_coeff': 5.816113913125069e-27, 'num_module_steps_trained': 60800, 'diff_num_grad_updates_vs_sampler_policy': np.float32(1.0), 'vf_loss': np.float32(0.016424894), 'weights_seq_no': 197.0, 'policy_loss': np.float32(-0.01895447), 'mean_kl_loss': np.float32(0.0022929795), 'entropy': np.float32(0.1812606), 'curr_entropy_coeff': 0.0, 'num_module_steps_trained_lifetime': 11934848, 'default_optimizer_learning_rate': 5e-05, 'total_loss': np.float32(-0.0025295801), 'gradients_default_optimizer_global_norm': np.float32(1.0842315)}, '__all_modules__': {'learner_connector': {'timers': {'connectors': {'numpy_to_tensor': 0.00205946189287807, 'add_states_from_episodes_to_batch': 1.6668585055998257e-05, 'batch_individual_items': 0.05142815608689856, 'add_columns_from_episodes_to_train_batch': 0.08671510919793012, 'general_advantage_estimation': 0.09626779045184139, 'add_observations_from_episodes_to_batch': 0.00041026792363030003, 'add_time_dim_to_batch_and_zero_pad': 4.38585313367988e-05, 'add_one_ts_to_episodes_and_truncate': 0.006832024660502486}}, 'connector_pipeline_timer': 0.24429735557346977}, 'learner_connector_sum_episodes_length_in': 2000.0, 'num_env_steps_trained_lifetime': 188087856, 'num_module_steps_trained_lifetime': 11934848, 'num_e ...
#   path='/home/ypp/ray_results/PPO_2025-05-11_05-54-47/PPO_WorkerScaling_a0813_00000_0_2025-05-11_05-54-47',
#   filesystem='local',
#   checkpoint=None
# )

# %%
# Plot the reward per iteration
plt.figure(figsize=(6, 6))
plt.plot(iter_setps, episode_reward, label='Reward per step')
plt.xlabel('Step')
plt.ylabel('Reward')
plt.title('Reward per step')
plt.legend()
plt.grid()
plt.show()
# Save the results to a CSV file
output_csv_path = os.path.join('./tmp', 'rllib_results.csv')
os.makedirs('./tmp', exist_ok=True)
with open(output_csv_path, 'w', newline='') as csvfile:
    fieldnames = ['step', 'reward']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for step, reward in zip(iter_setps, episode_reward):
        writer.writerow({'step': step, 'reward': reward})
print(f"✅ RLlib 训练结果已保存到 {output_csv_path}")
# Out:
# ✅ RLlib 训练结果已保存到 ./tmp/rllib_results.csv

# %%
from ray.rllib.core import DEFAULT_MODULE_ID
from ray.rllib.core.columns import Columns
from ray.rllib.core.rl_module.rl_module import RLModule
from ray.rllib.utils.numpy import convert_to_numpy, softmax

rl_module = RLModule.from_checkpoint(
    os.path.join(
        best_result.checkpoint.path,
        "learner_group",
        "learner",
        "rl_module",
        DEFAULT_MODULE_ID,
    )
)

tasks, base_time = load_tasks_from_csv('./tmp')
env = WorkerScaling(config={"observe_length": 36})
env.init_simulator(tasks, base_time)
simulator = env.simulator

action = init_workers - min_workers
while True:
    obs, reward, terminated, truncated, _ = env.step(action)
    if terminated or truncated:
        break
    input_dict = {Columns.OBS: torch.from_numpy(obs).unsqueeze(0)}
    rl_module_out = rl_module.forward_inference(input_dict)
    logits = convert_to_numpy(rl_module_out[Columns.ACTION_DIST_INPUTS])
    # get action with the largest probability
    action = np.argmax(logits[0])

print("🤩 总reward为：", sum([m.reward for m in simulator.metrics]))
simulator.plot_metrics("./tmp")
save_metrics_to_csv(simulator.metrics, './tmp')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 8
#       3 from ray.rllib.core.rl_module.rl_module import RLModule
#       4 from ray.rllib.utils.numpy import convert_to_numpy, softmax
#       6 rl_module = RLModule.from_checkpoint(
#       7     os.path.join(
# ----> 8         best_result.checkpoint.path,
#       9         "learner_group",
#      10         "learner",
#      11         "rl_module",
#      12         DEFAULT_MODULE_ID,
#      13     )
#      14 )
#      16 tasks, base_time = load_tasks_from_csv('./tmp')
#      17 env = WorkerScaling(config={"observe_length": 36})
#
# AttributeError: 'NoneType' object has no attribute 'path'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取 CSV 文件
df_a = pd.read_csv('./tmp/rllib_forecast_results.csv')
df_b = pd.read_csv('./tmp/rllib_results.csv')

# 将 step 映射到 [0, 1]
df_a["step_scaled"] = df_a["step"] / df_a["step"].max()
df_b["step_scaled"] = df_b["step"] / df_b["step"].max()

# 绘图
plt.figure(figsize=(8, 6))
plt.plot(df_a["step_scaled"], df_a["reward"], label="A")
plt.plot(df_b["step_scaled"], df_b["reward"], label="B")

plt.xlabel("Normalized Step")
plt.ylabel("Reward")
plt.title("Comparison with X-axis Normalized")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
